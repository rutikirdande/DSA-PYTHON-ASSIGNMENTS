# %%
# <aside>
# 💡 Question-1

# Given a binary tree, your task is to find subtree with maximum sum in tree.

# Examples:

# Input1 :       

#        1

#      /   \

#    2      3

#   / \    / \

# 4   5  6   7

# Output1 : 28

# As all the tree elements are positive, the largest subtree sum is equal to sum of all tree elements.

# Input2 :

#        1

#      /    \

#   -2      3

#   / \    /  \

# 4   5  -6   2

# Output2 : 7

# Subtree with largest sum is :

#  -2

#  / \

# 4   5

# Also, entire tree sum is also 7.

# </aside>

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def maxSumSubtree(node):
    if node is None:
        return 0

    leftSum = maxSumSubtree(node.left)
    rightSum = maxSumSubtree(node.right)
    subtreeSum = node.val + leftSum + rightSum

    global maxSum
    maxSum = max(maxSum, subtreeSum)

    return subtreeSum

def maxSumSubtreeWrapper(root):
    global maxSum
    maxSum = float('-inf')
    maxSumSubtree(root)
    return maxSum
# Example 1
root1 = TreeNode(1)
root1.left = TreeNode(2)
root1.right = TreeNode(3)
root1.left.left = TreeNode(4)
root1.left.right = TreeNode(5)
root1.right.left = TreeNode(6)
root1.right.right = TreeNode(7)
print(maxSumSubtreeWrapper(root1))  # Output: 28

# Example 2
root2 = TreeNode(1)
root2.left = TreeNode(-2)
root2.right = TreeNode(3)
root2.left.left = TreeNode(4)
root2.left.right = TreeNode(5)
root2.right.left = TreeNode(-6)
root2.right.right = TreeNode(2)
print(maxSumSubtreeWrapper(root2))  # Output: 7
# Out:
# 28
# 7

# %%
# <aside>
# 💡 Question-2

# Construct the BST (Binary Search Tree) from its given level order traversal.

# Example:

# Input: arr[] = {7, 4, 12, 3, 6, 8, 1, 5, 10}

# Output: BST:

#             7

#          /    \

#        4     12

#      /  \     /

#     3   6  8

#    /    /     \

#  1    5      10

# </aside>

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def constructBST(levelOrder):
    if not levelOrder:
        return None

    root = TreeNode(levelOrder[0])
    queue = [root]
    i = 1

    while i < len(levelOrder):
        node = queue.pop(0)

        if i < len(levelOrder) and levelOrder[i] < node.val:
            node.left = TreeNode(levelOrder[i])
            queue.append(node.left)
            i += 1

        if i < len(levelOrder) and levelOrder[i] > node.val:
            node.right = TreeNode(levelOrder[i])
            queue.append(node.right)
            i += 1

    return root

# %%
# <aside>
# 💡 Question-3

# Given an array of size n. The problem is to check whether the given array can represent the level order traversal of a Binary Search Tree or not.

# Examples:

# Input1 : arr[] = {7, 4, 12, 3, 6, 8, 1, 5, 10}

# Output1 : Yes

# For the given arr[], the Binary Search Tree is:

#             7

#          /    \

#        4     12

#      /  \     /

#     3   6  8

#    /    /     \

#  1    5      10

# Input2 : arr[] = {11, 6, 13, 5, 12, 10}

# Output2 : No

# The given arr[] does not represent the level order traversal of a BST.

# </aside>

def isLevelOrderBST(levelOrder):
    if not levelOrder:
        return True

    stack = [levelOrder[0]]
    i = 1

    while i < len(levelOrder):
        if not stack:
            return False

        if levelOrder[i] < stack[-1]:
            stack.append(levelOrder[i])
            i += 1
        else:
            while stack and levelOrder[i] > stack[-1]:
                last = stack.pop()

            stack.append(levelOrder[i])
            i += 1

    while stack and i < len(levelOrder):
        if levelOrder[i] < stack[-1]:
            return False

        i += 1

    return True


levelOrder1 = [7, 4, 12, 3, 6, 8, 1, 5, 10]
print(isLevelOrderBST(levelOrder1))  # Output: True

levelOrder2 = [11, 6, 13, 5, 12, 10]
print(isLevelOrderBST(levelOrder2))  # Output: False
# Out:
# True
# True
